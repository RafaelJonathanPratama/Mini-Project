# %% [markdown]
# <a href="https://colab.research.google.com/github/RafaelJonathanPratama/Mini-Project/blob/main/Perbandingan%20penyakit%20pernapasan%20di%20tahun%202010%20dan%20di%20tahun%202025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# Data prevalensi CRD global (dalam juta kasus)
tahun = ['2010','2025']
prevalensi = [389.7, 544.9]

# Membuat pie chart
plt.figure(figsize=(7, 7))
plt.pie(prevalensi, labels=tahun, autopct='%1.1f%%', startangle=90, colors=['#66b3ff', '#ff6666'])
plt.title('Tren Prevalensi Penyakit Pernapasan Kronis Global (1990 vs 2017)')
plt.axis('equal')  # Membuat pie chart berbentuk lingkaran sempurna
plt.show()
